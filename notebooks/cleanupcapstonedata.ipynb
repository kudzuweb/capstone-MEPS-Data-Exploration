# %%
import pandas as pd
import os

# %% [markdown]
# #### Functions

# %%
#define function to read in V9 files and add to dictionary
def readV9(source, ids, dict):
    dict = {}
    ps = []
    for id in ids:
        if os.path.exists(f'../data/{source}/{id}.sas7bdat'):
            df = pd.read_sas(f'../data/{source}/{id}.sas7bdat', encoding= 'utf-8')
            key = id
            dict[key] = df
            p = ps.append('Got it!')
        else:
            ps.append('Nope.')
    return ps, dict

# %%
#define function to read in sas files and add to dictionary
def readSAS(source, ids, dict):
    ps = []
    for id in ids:
        if os.path.exists(f'../data/{source}/{id}.ssp'):
            df = pd.read_sas(f'../data/{source}/{id}.ssp', format = 'xport', encoding= 'utf-8')
            key = id
            dict[key] = df
            p = ps.append('Got it!')
        else:
            ps.append('Nope.')
    return ps, dict

# %%
#define function to rename dfs to appropriate filenames

def renameMasters(dict, start_year, prefix, ids):
    renamed_dict = {}
    current_year = start_year

    for original_key in ids:
        if original_key in dict:
            new_key = f'{prefix}_{current_year}'
            renamed_dict[new_key] = dict[original_key]
            current_year -= 1

    return renamed_dict

# %%
#define function to export each df in dictionary to csv
def shipData(dest, dir, dict):
    if not os.path.exists(dir):
                os.makedirs(dir)
    for df in dict:
        dict[df].to_csv(f'../data/{dest}/{df}.csv', index= False)
    return print('data shipped!')

# %% [markdown]
# #### *Population Characteristics*

# %%
#call function to read in V9 files and add to dictionary
ids = ['h233', 'h224', 'h216', 'h209', 'h201']
fpcdata = {}

ps, fpcdata = readV9('fpc', ids, fpcdata)

# %%
#call function to read in SAS files and add to dictionary
ids = ['h192', 'h181', 'h171', 'h163', 'h155']

ps, fpcdata = readSAS('fpc', ids, fpcdata)

# %%
#call function to rename dfs to appropriate filenames
ids = ['h233', 'h224', 'h216', 'h209', 'h201', 'h192', 'h181', 'h171', 'h163', 'h155']

fpcdata = renameMasters(fpcdata, 2021, 'fpc_data', ids)

# %%
fpcdata['fpc_data_2021']
# Out:
#             DUID    PID    DUPERSID  PANEL FAMID31 FAMID42 FAMID53 FAMID21  \
# 0      2320005.0  101.0  2320005101   23.0       A       A       A       A
# 1      2320005.0  102.0  2320005102   23.0       A       A       A       A
# 2      2320006.0  101.0  2320006101   23.0       A       A       A       A
# 3      2320006.0  102.0  2320006102   23.0       B       B       B       B
# 4      2320006.0  103.0  2320006103   23.0       A       A       A       A
# ...          ...    ...         ...    ...     ...     ...     ...     ...
# 28331  2689506.0  102.0  2689506102   26.0       A       A       A       A
# 28332  2689507.0  101.0  2689507101   26.0       A       A       A       A
# 28333  2689507.0  102.0  2689507102   26.0       A       A       A       A
# 28334  2689507.0  103.0  2689507103   26.0       A       A       A       A
# 28335  2689507.0  104.0  2689507104   26.0       A       A       A       A
#
#       FAMIDYR CPSFAMID  ...  RXPTR21  RXOTH21      PERWT21F      FAMWT21F  \
# 0           A        A  ...      0.0      0.0   6785.015684   7187.249055
# 1           A        A  ...      0.0      0.0   6176.506584   7187.249055
# 2           A        A  ...      0.0      0.0   1599.364175   1530.856371
# 3           B        B  ...      0.0      0.0   1649.344739   2314.506726
# 4           A        A  ...      0.0      0.0   2891.997868   1530.856371
# ...       ...      ...  ...      ...      ...           ...           ...
# 28331       A        A  ...   1088.0      0.0  25535.854890  26300.839968
# 28332       A        A  ...      0.0      0.0  38724.996556  38883.467779
# 28333       A        A  ...      0.0      0.0  34505.439704  38883.467779
# 28334       A        A  ...      0.0      0.0  23975.435327  38883.467779
# 28335       A        A  ...      0.0      0.0  27813.061477  38883.467779
#
#            FAMWT21C      SAQWT21F  DIABW21F     SDOHWT21F  VARSTR  VARPSU
# 0       7187.249055      0.000000       0.0   8941.111966  2079.0     1.0
# 1       7187.249055      0.000000       0.0      0.000000  2079.0     1.0
# 2       1530.856371      0.000000       0.0   1990.417108  2028.0     1.0
# 3       2314.506726      0.000000       0.0   2317.855238  2028.0     1.0
# 4       1530.856371      0.000000       0.0   2708.864797  2028.0     1.0
# ...             ...           ...       ...           ...     ...     ...
# 28331  26300.839968  28680.136581       0.0  32665.515501  2049.0     2.0
# 28332  38883.467779      0.000000       0.0  39080.893060  2104.0     2.0
# 28333  38883.467779      0.000000       0.0  40274.473639  2104.0     2.0
# 28334  38883.467779      0.000000       0.0      0.000000  2104.0     2.0
# 28335  38883.467779      0.000000       0.0      0.000000  2104.0     2.0
#
# [28336 rows x 1488 columns]

# %%
#call function to export csvs
dest = 'fpc'
dir = f'../data/{dest}'
dict = fpcdata

shipData(dest, dir, dict)
# Out:
# data shipped!

# %% [markdown]
# #### *Hospital Inpatient Stays*

# %%
#call function to read in V9 files and add to dictionary
ids = ['h229d', 'h220d', 'h213d', 'h206d', 'h197d']
hisdata = {}

ps, hisdata = readV9('his', ids, hisdata)

# %%
#call function to read in SAS files and add to dictionary
ids = ['h188d', 'h178d', 'h168d', 'h160d', 'h152d']

ps, hisdata = readSAS('his', ids, hisdata)

# %%
#call function to rename dfs to appropriate filenames
ids = ['h229d', 'h220d', 'h213d', 'h206d', 'h197d', 'h188d', 'h178d', 'h168d', 'h160d', 'h152d']

hisdata = renameMasters(hisdata, 2021, 'his_data', ids)

# %%
hisdata['his_data_2021']
# Out:
#            DUID    PID    DUPERSID           EVNTIDX  EVENTRN  \
# 0     2320005.0  102.0  2320005102  2320005102201901      8.0
# 1     2320018.0  102.0  2320018102  2320018102215301      8.0
# 2     2320018.0  102.0  2320018102  2320018102216801      9.0
# 3     2320045.0  102.0  2320045102  2320045102207001      9.0
# 4     2320063.0  101.0  2320063101  2320063101201201      8.0
# ...         ...    ...         ...               ...      ...
# 2552  2689409.0  101.0  2689409101  2689409101001401      2.0
# 2553  2689415.0  101.0  2689415101  2689415101003301      3.0
# 2554  2689423.0  102.0  2689423102  2689423102000501      1.0
# 2555  2689438.0  101.0  2689438101  2689438101000801      2.0
# 2556  2689438.0  101.0  2689438101  2689438101000901      2.0
#
#               ERHEVIDX FFEEIDX  PANEL  MPCDATA  IPBEGYR  ...  IPDOF21X  \
# 0     2320005102202001      -1   23.0      2.0   2021.0  ...       0.0
# 1                   -1      -1   23.0      1.0   2021.0  ...       0.0
# 2     2320018102216201      -1   23.0      1.0   2021.0  ...       0.0
# 3                   -1      -1   23.0      2.0   2021.0  ...       0.0
# 4     2320063101201401      -1   23.0      2.0   2021.0  ...       0.0
# ...                ...     ...    ...      ...      ...  ...       ...
# 2552                -1      -1   26.0      1.0   2021.0  ...       0.0
# 2553  2689415101003401      -1   26.0      2.0   2021.0  ...       0.0
# 2554                -1      -1   26.0      2.0   2021.0  ...       0.0
# 2555                -1      -1   26.0      2.0   2021.0  ...       0.0
# 2556                -1      -1   26.0      2.0   2021.0  ...       0.0
#
#       IPDSL21X  IPDWC21X  IPDOT21X  IPDXP21X  IPDTC21X  IMPFLAG      PERWT21F  \
# 0          0.0       0.0       0.0    699.35   3846.84      3.0   6176.506584
# 1          0.0       0.0       0.0    178.08   1158.00      2.0   5094.242350
# 2          0.0       0.0       0.0    406.76   2944.31      2.0   5094.242350
# 3          0.0       0.0       0.0  10059.60  15301.00      1.0  11044.653629
# 4          0.0       0.0       0.0    594.50   1497.90      3.0   5975.388794
# ...        ...       ...       ...       ...       ...      ...           ...
# 2552       0.0       0.0       0.0     35.19    166.00      2.0   5718.681493
# 2553       0.0       0.0       0.0    229.50   2346.46      3.0   5897.586331
# 2554       0.0       0.0       0.0      0.00      0.00      4.0  23309.244843
# 2555       0.0       0.0       0.0   1122.01   1512.46      3.0   7718.988598
# 2556       0.0       0.0       0.0   2075.57   4420.43      3.0   7718.988598
#
#       VARSTR  VARPSU
# 0     2079.0     1.0
# 1     2077.0     1.0
# 2     2077.0     1.0
# 3     2025.0     1.0
# 4     2006.0     3.0
# ...      ...     ...
# 2552  2044.0     4.0
# 2553  2034.0     1.0
# 2554  2089.0     2.0
# 2555  2029.0     1.0
# 2556  2029.0     1.0
#
# [2557 rows x 50 columns]

# %%
#call function to export csvs
dest = 'his'
dir = f'../data/{dest}'
dict = hisdata

shipData(dest, dir, dict)
# Out:
# data shipped!

# %% [markdown]
# #### *Emergency Room Visits*

# %%
#call function to read in V9 files and add to dictionary
ids = ['h229e', 'h220e', 'h213e', 'h206e', 'h197e']
ervdata = {}

ps, ervdata = readV9('erv', ids, ervdata)

# %%
#call function to read in SAS files and add to dictionary
ids = ['h188e', 'h178e', 'h168e', 'h160e', 'h152e']

ps, ervdata = readSAS('erv', ids, ervdata)

# %%
#call function to rename dfs to appropriate filenames
ids = ['h229e', 'h220e', 'h213e', 'h206e', 'h197e', 'h188e', 'h178e', 'h168e', 'h160e', 'h152e']

ervdata = renameMasters(ervdata, 2021, 'erv_data', ids)

# %%
ervdata['erv_data_2021']
# Out:
#            DUID    PID    DUPERSID           EVNTIDX  EVENTRN  \
# 0     2320005.0  102.0  2320005102  2320005102202001      8.0
# 1     2320018.0  102.0  2320018102  2320018102213601      8.0
# 2     2320018.0  102.0  2320018102  2320018102216201      9.0
# 3     2320025.0  101.0  2320025101  2320025101213301      8.0
# 4     2320045.0  102.0  2320045102  2320045102206901      9.0
# ...         ...    ...         ...               ...      ...
# 5439  2689462.0  101.0  2689462101  2689462101000901      1.0
# 5440  2689467.0  101.0  2689467101  2689467101000101      1.0
# 5441  2689468.0  101.0  2689468101  2689468101000101      1.0
# 5442  2689468.0  101.0  2689468101  2689468101000501      3.0
# 5443  2689497.0  101.0  2689497101  2689497101003201      3.0
#
#               ERHEVIDX FFEEIDX  PANEL  MPCDATA  ERDATEYR  ...  ERDOF21X  \
# 0     2320005102201901      -1   23.0      2.0    2021.0  ...       0.0
# 1                   -1      -1   23.0      1.0    2021.0  ...       0.0
# 2     2320018102216801      -1   23.0      1.0    2021.0  ...       0.0
# 3                   -1      -1   23.0      1.0    2021.0  ...       0.0
# 4                   -1      -1   23.0      2.0    2021.0  ...       0.0
# ...                ...     ...    ...      ...       ...  ...       ...
# 5439                -1      -1   26.0      2.0    2021.0  ...       0.0
# 5440                -1      -1   26.0      1.0    2021.0  ...       0.0
# 5441                -1      -1   26.0      1.0    2021.0  ...       0.0
# 5442                -1      -1   26.0      2.0    2021.0  ...       0.0
# 5443                -1      -1   26.0      2.0    2021.0  ...       0.0
#
#       ERDSL21X  ERDWC21X  ERDOT21X  ERDXP21X  ERDTC21X  IMPFLAG      PERWT21F  \
# 0          0.0       0.0       0.0      0.00      0.00      0.0   6176.506584
# 1          0.0       0.0       0.0    109.21   1517.00      3.0   5094.242350
# 2          0.0       0.0       0.0     11.35   1154.00      0.0   5094.242350
# 3          0.0       0.0       0.0    360.72   2107.00      2.0   6891.611614
# 4          0.0       0.0       0.0      0.00      0.00      1.0  11044.653629
# ...        ...       ...       ...       ...       ...      ...           ...
# 5439       0.0       0.0       0.0    412.24   2122.59      3.0  13978.006068
# 5440       0.0       0.0       0.0    411.69   1776.00      2.0  11293.073523
# 5441       0.0       0.0       0.0     97.87   2254.23      2.0   5373.483323
# 5442       0.0       0.0       0.0      0.00      0.00      3.0   5373.483323
# 5443       0.0       0.0       0.0    510.55   1542.14      3.0   3432.219257
#
#       VARSTR  VARPSU
# 0     2079.0     1.0
# 1     2077.0     1.0
# 2     2077.0     1.0
# 3     2034.0     3.0
# 4     2025.0     1.0
# ...      ...     ...
# 5439  2082.0     1.0
# 5440  2051.0     2.0
# 5441  2075.0     4.0
# 5442  2075.0     4.0
# 5443  2025.0     3.0
#
# [5444 rows x 53 columns]

# %%
#call function to export csvs
dest = 'erv'
dir = f'../data/{dest}'
dict = ervdata

shipData(dest, dir, dict)
# Out:
# data shipped!

# %% [markdown]
# #### *Office-Based Visits*

# %%
#call function to read in V9 files and add to dictionary
ids = ['h229g', 'h220g', 'h213g', 'h206g', 'h197g']
obvdata = {}

ps, obvdata = readV9('obv', ids, obvdata)

# %%
#call function to read in SAS files and add to dictionary
ids = ['h188g', 'h178g', 'h168g', 'h160g', 'h152g']

ps, obvdata = readSAS('obv', ids, obvdata)

# %%
#call function to rename dfs to appropriate filenames
ids = ['h229g', 'h220g', 'h213g', 'h206g', 'h197g', 'h188g', 'h178g', 'h168g', 'h160g', 'h152g']

obvdata = renameMasters(obvdata, 2021, 'obv_data', ids)

# %%
obvdata['obv_data_2021']
# Out:
#            DUID    PID  DUPERSID       EVNTIDX  EVENTRN FFEEIDX  PANEL  \
# 0       10001.0  101.0  10001101  100011010021      1.0      -1   21.0
# 1       10001.0  101.0  10001101  100011010031      1.0      -1   21.0
# 2       10001.0  101.0  10001101  100011010041      1.0      -1   21.0
# 3       10001.0  101.0  10001101  100011010051      1.0      -1   21.0
# 4       10001.0  101.0  10001101  100011010061      1.0      -1   21.0
# ...         ...    ...       ...           ...      ...     ...    ...
# 164998  80570.0  101.0  80570101  805701010631      5.0      -1   20.0
# 164999  80570.0  101.0  80570101  805701010641      5.0      -1   20.0
# 165000  80570.0  101.0  80570101  805701010651      5.0      -1   20.0
# 165001  80570.0  101.0  80570101  805701010661      5.0      -1   20.0
# 165002  80570.0  101.0  80570101  805701010671      5.0      -1   20.0
#
#         MPCELIG  MPCDATA  OBDATEYR  ...       OBWC16X       OBOR16X  \
# 0           2.0      2.0    2016.0  ...  5.397605e-79  5.397605e-79
# 1           2.0      2.0    2016.0  ...  5.397605e-79  5.397605e-79
# 2           1.0      2.0    2016.0  ...  5.397605e-79  5.397605e-79
# 3           1.0      2.0    2016.0  ...  5.397605e-79  5.397605e-79
# 4           1.0      2.0    2016.0  ...  5.397605e-79  5.397605e-79
# ...         ...      ...       ...  ...           ...           ...
# 164998      1.0      2.0    2016.0  ...  5.397605e-79  5.397605e-79
# 164999      1.0      1.0    2016.0  ...  5.397605e-79  5.397605e-79
# 165000      2.0      2.0    2016.0  ...  5.397605e-79  5.397605e-79
# 165001      2.0      2.0    2016.0  ...  5.397605e-79  5.397605e-79
# 165002      2.0      2.0    2016.0  ...  5.397605e-79  5.397605e-79
#
#              OBOU16X       OBOT16X  OBXP16X  OBTC16X  IMPFLAG      PERWT16F  \
# 0       5.397605e-79  5.397605e-79   206.00   206.00      4.0  12999.552725
# 1       5.397605e-79  5.397605e-79    55.00    46.00      4.0  12999.552725
# 2       5.397605e-79  5.397605e-79   203.00   203.00      4.0  12999.552725
# 3       5.397605e-79  5.397605e-79    69.72   125.00      4.0  12999.552725
# 4       5.397605e-79  5.397605e-79    71.15   100.00      3.0  12999.552725
# ...              ...           ...      ...      ...      ...           ...
# 164998  5.397605e-79  5.397605e-79   124.70   124.70      4.0  13195.265632
# 164999  5.397605e-79  5.397605e-79   184.71   210.00      2.0  13195.265632
# 165000  5.397605e-79  5.397605e-79   130.00   130.00      4.0  13195.265632
# 165001  5.397605e-79  5.397605e-79    32.00    32.00      3.0  13195.265632
# 165002  5.397605e-79  5.397605e-79    32.00    44.34      3.0  13195.265632
#
#         VARSTR  VARPSU
# 0       1021.0     1.0
# 1       1021.0     1.0
# 2       1021.0     1.0
# 3       1021.0     1.0
# 4       1021.0     1.0
# ...        ...     ...
# 164998  1126.0     1.0
# 164999  1126.0     1.0
# 165000  1126.0     1.0
# 165001  1126.0     1.0
# 165002  1126.0     1.0
#
# [165003 rows x 52 columns]

# %%
#call function to export csvs
dest = 'obv'
dir = f'../data/{dest}'
dict = obvdata

shipData(dest, dir, dict)
# Out:
# data shipped!
