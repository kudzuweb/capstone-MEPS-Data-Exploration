# %%
import pandas as pd
import os

# %% [markdown]
# ##### Code may be commented out where running it at the wrong time could result in erroneous exports.

# %% [markdown]
# #### Define Functions

# %%
#define function to read in V9 files and add to dictionary
def readV9(source, ids, dict):
    dict = {}
    ps = []
    for id in ids:
        if os.path.exists(f'../data/{source}/{id}.sas7bdat'):
            df = pd.read_sas(f'../data/{source}/{id}.sas7bdat', encoding= 'utf-8')
            key = id
            dict[key] = df
            p = ps.append('Got it!')
        else:
            ps.append('Nope.')
    return ps, dict

# %%
#define function to read in sas files and add to dictionary
def readSAS(source, ids, dict):
    ps = []
    for id in ids:
        if os.path.exists(f'../data/{source}/{id}.ssp'):
            df = pd.read_sas(f'../data/{source}/{id}.ssp', format = 'xport', encoding= 'utf-8')
            key = id
            dict[key] = df
            p = ps.append('Got it!')
        else:
            ps.append('Nope.')
    return ps, dict

# %%
#define function to read in codebooks and add to dictionary
def readCBs(source, year, dict):
    ps = []
    for year in years:
        if os.path.exists(f'../data/{source}_codebooks/{source}_cb_{year}.csv'):
            df = pd.read_csv(f'../data/{source}_codebooks/{source}_cb_{year}.csv')
            key = f'{source}_cb_{year}'
            dict[key] = df
            p = ps.append('Got it!')
        else:
            ps.append('Nope.')
    return ps, dict

# %%
#define function to rename dfs to appropriate filenames

def renameMasters(dict, start_year, prefix, ids):
    renamed_dict = {}
    current_year = start_year

    for original_key in ids:
        if original_key in dict:
            new_key = f'{prefix}_{current_year}'
            renamed_dict[new_key] = dict[original_key]
            current_year -= 1

    return renamed_dict

# %%
#define function to export each df in dictionary to csv
def shipData(dest, dir, dict):
    if not os.path.exists(dir):
                os.makedirs(dir)
    for df in dict:
        dict[df].to_csv(f'../data/{dest}/{df}.csv', index= False)
    return print('data shipped!')

# %% [markdown]
# #### *Population Characteristics*

# %%
#call function to read in V9 files and add to dictionary
ids = ['h233', 'h224', 'h216', 'h209', 'h201']
fpcdata = {}

ps, fpcdata = readV9('fpc', ids, fpcdata)

# %%
#call function to read in SAS files and add to dictionary
ids = ['h192', 'h181', 'h171', 'h163', 'h155']

ps, fpcdata = readSAS('fpc', ids, fpcdata)

# %%
#call function to rename dfs to appropriate filenames
ids = ['h233', 'h224', 'h216', 'h209', 'h201', 'h192', 'h181', 'h171', 'h163', 'h155']

fpcdata = renameMasters(fpcdata, 2021, 'fpc_data', ids)

# %%
fpcdata['fpc_data_2021']
# Out:
#             DUID    PID    DUPERSID  PANEL FAMID31 FAMID42 FAMID53 FAMID21  \
# 0      2320005.0  101.0  2320005101   23.0       A       A       A       A
# 1      2320005.0  102.0  2320005102   23.0       A       A       A       A
# 2      2320006.0  101.0  2320006101   23.0       A       A       A       A
# 3      2320006.0  102.0  2320006102   23.0       B       B       B       B
# 4      2320006.0  103.0  2320006103   23.0       A       A       A       A
# ...          ...    ...         ...    ...     ...     ...     ...     ...
# 28331  2689506.0  102.0  2689506102   26.0       A       A       A       A
# 28332  2689507.0  101.0  2689507101   26.0       A       A       A       A
# 28333  2689507.0  102.0  2689507102   26.0       A       A       A       A
# 28334  2689507.0  103.0  2689507103   26.0       A       A       A       A
# 28335  2689507.0  104.0  2689507104   26.0       A       A       A       A
#
#       FAMIDYR CPSFAMID  ...  RXOTH21      PERWT21F      FAMWT21F  \
# 0           A        A  ...      0.0   6785.015684   7187.249055
# 1           A        A  ...      0.0   6176.506584   7187.249055
# 2           A        A  ...      0.0   1599.364175   1530.856371
# 3           B        B  ...      0.0   1649.344739   2314.506726
# 4           A        A  ...      0.0   2891.997868   1530.856371
# ...       ...      ...  ...      ...           ...           ...
# 28331       A        A  ...      0.0  25535.854890  26300.839968
# 28332       A        A  ...      0.0  38724.996556  38883.467779
# 28333       A        A  ...      0.0  34505.439704  38883.467779
# 28334       A        A  ...      0.0  23975.435327  38883.467779
# 28335       A        A  ...      0.0  27813.061477  38883.467779
#
#            FAMWT21C      SAQWT21F DIABW21F     SDOHWT21F  VARSTR  VARPSU  YEAR
# 0       7187.249055      0.000000      0.0   8941.111966  2079.0     1.0  2021
# 1       7187.249055      0.000000      0.0      0.000000  2079.0     1.0  2021
# 2       1530.856371      0.000000      0.0   1990.417108  2028.0     1.0  2021
# 3       2314.506726      0.000000      0.0   2317.855238  2028.0     1.0  2021
# 4       1530.856371      0.000000      0.0   2708.864797  2028.0     1.0  2021
# ...             ...           ...      ...           ...     ...     ...   ...
# 28331  26300.839968  28680.136581      0.0  32665.515501  2049.0     2.0  2021
# 28332  38883.467779      0.000000      0.0  39080.893060  2104.0     2.0  2021
# 28333  38883.467779      0.000000      0.0  40274.473639  2104.0     2.0  2021
# 28334  38883.467779      0.000000      0.0      0.000000  2104.0     2.0  2021
# 28335  38883.467779      0.000000      0.0      0.000000  2104.0     2.0  2021
#
# [28336 rows x 1489 columns]

# %%
#add year column
years = [2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012]

# Adding a new column with the respective year to each DataFrame
for (key, df), year in zip(fpcdata.items(), years):
    df['YEAR'] = year
# Out:
# /var/folders/f_/3c498dtd4q9cs_ll7zmc_9hw0000gn/T/ipykernel_52714/2540868195.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['YEAR'] = year
# /var/folders/f_/3c498dtd4q9cs_ll7zmc_9hw0000gn/T/ipykernel_52714/2540868195.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['YEAR'] = year
# /var/folders/f_/3c498dtd4q9cs_ll7zmc_9hw0000gn/T/ipykernel_52714/2540868195.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['YEAR'] = year
# /var/folders/f_/3c498dtd4q9cs_ll7zmc_9hw0000gn/T/ipykernel_52714/2540868195.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['YEAR'] = year
# /var/folders/f_/3c498dtd4q9cs_ll7zmc_9hw0000gn/T/ipykernel_52714/2540868195.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['YEAR'] = year

# %%
#read in codebooks
# years = ['2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012']
# fpcCBs = {}

# ps, fpcCBs = readCBs('fpc', years, fpcCBs)
# ps

# %%
# fpcCBs['fpc_cb_2012']

# %%
# !ls ../data/fpc_codebooks

# %%
#call function to export csvs
dest = 'fpc'
dir = f'../data/{dest}'
dict = fpcdata

shipData(dest, dir, dict)
# Out:
# data shipped!

# %% [markdown]
# #### *Hospital Inpatient Stays*

# %%
#call function to read in V9 files and add to dictionary
ids = ['h229d', 'h220d', 'h213d', 'h206d', 'h197d']
hisdata = {}

ps, hisdata = readV9('his', ids, hisdata)

# %%
#call function to read in SAS files and add to dictionary
ids = ['h188d', 'h178d', 'h168d', 'h160d', 'h152d']

ps, hisdata = readSAS('his', ids, hisdata)

# %%
#call function to rename dfs to appropriate filenames
ids = ['h229d', 'h220d', 'h213d', 'h206d', 'h197d', 'h188d', 'h178d', 'h168d', 'h160d', 'h152d']

hisdata = renameMasters(hisdata, 2021, 'his_data', ids)

# %%
hisdata['his_data_2021']
# Out:
#            DUID    PID    DUPERSID           EVNTIDX  EVENTRN  \
# 0     2320005.0  102.0  2320005102  2320005102201901      8.0
# 1     2320018.0  102.0  2320018102  2320018102215301      8.0
# 2     2320018.0  102.0  2320018102  2320018102216801      9.0
# 3     2320045.0  102.0  2320045102  2320045102207001      9.0
# 4     2320063.0  101.0  2320063101  2320063101201201      8.0
# ...         ...    ...         ...               ...      ...
# 2552  2689409.0  101.0  2689409101  2689409101001401      2.0
# 2553  2689415.0  101.0  2689415101  2689415101003301      3.0
# 2554  2689423.0  102.0  2689423102  2689423102000501      1.0
# 2555  2689438.0  101.0  2689438101  2689438101000801      2.0
# 2556  2689438.0  101.0  2689438101  2689438101000901      2.0
#
#               ERHEVIDX FFEEIDX  PANEL  MPCDATA  IPBEGYR  ...  IPDSL21X  \
# 0     2320005102202001      -1   23.0      2.0   2021.0  ...       0.0
# 1                   -1      -1   23.0      1.0   2021.0  ...       0.0
# 2     2320018102216201      -1   23.0      1.0   2021.0  ...       0.0
# 3                   -1      -1   23.0      2.0   2021.0  ...       0.0
# 4     2320063101201401      -1   23.0      2.0   2021.0  ...       0.0
# ...                ...     ...    ...      ...      ...  ...       ...
# 2552                -1      -1   26.0      1.0   2021.0  ...       0.0
# 2553  2689415101003401      -1   26.0      2.0   2021.0  ...       0.0
# 2554                -1      -1   26.0      2.0   2021.0  ...       0.0
# 2555                -1      -1   26.0      2.0   2021.0  ...       0.0
# 2556                -1      -1   26.0      2.0   2021.0  ...       0.0
#
#       IPDWC21X  IPDOT21X  IPDXP21X  IPDTC21X  IMPFLAG      PERWT21F  VARSTR  \
# 0          0.0       0.0    699.35   3846.84      3.0   6176.506584  2079.0
# 1          0.0       0.0    178.08   1158.00      2.0   5094.242350  2077.0
# 2          0.0       0.0    406.76   2944.31      2.0   5094.242350  2077.0
# 3          0.0       0.0  10059.60  15301.00      1.0  11044.653629  2025.0
# 4          0.0       0.0    594.50   1497.90      3.0   5975.388794  2006.0
# ...        ...       ...       ...       ...      ...           ...     ...
# 2552       0.0       0.0     35.19    166.00      2.0   5718.681493  2044.0
# 2553       0.0       0.0    229.50   2346.46      3.0   5897.586331  2034.0
# 2554       0.0       0.0      0.00      0.00      4.0  23309.244843  2089.0
# 2555       0.0       0.0   1122.01   1512.46      3.0   7718.988598  2029.0
# 2556       0.0       0.0   2075.57   4420.43      3.0   7718.988598  2029.0
#
#       VARPSU  YEAR
# 0        1.0  2021
# 1        1.0  2021
# 2        1.0  2021
# 3        1.0  2021
# 4        3.0  2021
# ...      ...   ...
# 2552     4.0  2021
# 2553     1.0  2021
# 2554     2.0  2021
# 2555     1.0  2021
# 2556     1.0  2021
#
# [2557 rows x 51 columns]

# %%
#add year column
years = [2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012]

# Adding a new column with the respective year to each DataFrame
for (key, df), year in zip(hisdata.items(), years):
    df['YEAR'] = year

# %%
#read in codebooks
# years = ['2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012']
# hisCBs = {}

# ps, hisCBs = readCBs('his', years, hisCBs)
# ps

# %%
#call function to export csvs
dest = 'his'
dir = f'../data/{dest}'
dict = hisdata

shipData(dest, dir, dict)
# Out:
# data shipped!

# %% [markdown]
# #### *Emergency Room Visits*

# %%
#call function to read in V9 files and add to dictionary
ids = ['h229e', 'h220e', 'h213e', 'h206e', 'h197e']
ervdata = {}

ps, ervdata = readV9('erv', ids, ervdata)

# %%
#call function to read in SAS files and add to dictionary
ids = ['h188e', 'h178e', 'h168e', 'h160e', 'h152e']

ps, ervdata = readSAS('erv', ids, ervdata)

# %%
#call function to rename dfs to appropriate filenames
ids = ['h229e', 'h220e', 'h213e', 'h206e', 'h197e', 'h188e', 'h178e', 'h168e', 'h160e', 'h152e']

ervdata = renameMasters(ervdata, 2021, 'erv_data', ids)

# %%
ervdata['erv_data_2021']
# Out:
#            DUID    PID    DUPERSID           EVNTIDX  EVENTRN  \
# 0     2320005.0  102.0  2320005102  2320005102202001      8.0
# 1     2320018.0  102.0  2320018102  2320018102213601      8.0
# 2     2320018.0  102.0  2320018102  2320018102216201      9.0
# 3     2320025.0  101.0  2320025101  2320025101213301      8.0
# 4     2320045.0  102.0  2320045102  2320045102206901      9.0
# ...         ...    ...         ...               ...      ...
# 5439  2689462.0  101.0  2689462101  2689462101000901      1.0
# 5440  2689467.0  101.0  2689467101  2689467101000101      1.0
# 5441  2689468.0  101.0  2689468101  2689468101000101      1.0
# 5442  2689468.0  101.0  2689468101  2689468101000501      3.0
# 5443  2689497.0  101.0  2689497101  2689497101003201      3.0
#
#               ERHEVIDX FFEEIDX  PANEL  MPCDATA  ERDATEYR  ...  ERDSL21X  \
# 0     2320005102201901      -1   23.0      2.0    2021.0  ...       0.0
# 1                   -1      -1   23.0      1.0    2021.0  ...       0.0
# 2     2320018102216801      -1   23.0      1.0    2021.0  ...       0.0
# 3                   -1      -1   23.0      1.0    2021.0  ...       0.0
# 4                   -1      -1   23.0      2.0    2021.0  ...       0.0
# ...                ...     ...    ...      ...       ...  ...       ...
# 5439                -1      -1   26.0      2.0    2021.0  ...       0.0
# 5440                -1      -1   26.0      1.0    2021.0  ...       0.0
# 5441                -1      -1   26.0      1.0    2021.0  ...       0.0
# 5442                -1      -1   26.0      2.0    2021.0  ...       0.0
# 5443                -1      -1   26.0      2.0    2021.0  ...       0.0
#
#       ERDWC21X  ERDOT21X  ERDXP21X  ERDTC21X  IMPFLAG      PERWT21F  VARSTR  \
# 0          0.0       0.0      0.00      0.00      0.0   6176.506584  2079.0
# 1          0.0       0.0    109.21   1517.00      3.0   5094.242350  2077.0
# 2          0.0       0.0     11.35   1154.00      0.0   5094.242350  2077.0
# 3          0.0       0.0    360.72   2107.00      2.0   6891.611614  2034.0
# 4          0.0       0.0      0.00      0.00      1.0  11044.653629  2025.0
# ...        ...       ...       ...       ...      ...           ...     ...
# 5439       0.0       0.0    412.24   2122.59      3.0  13978.006068  2082.0
# 5440       0.0       0.0    411.69   1776.00      2.0  11293.073523  2051.0
# 5441       0.0       0.0     97.87   2254.23      2.0   5373.483323  2075.0
# 5442       0.0       0.0      0.00      0.00      3.0   5373.483323  2075.0
# 5443       0.0       0.0    510.55   1542.14      3.0   3432.219257  2025.0
#
#       VARPSU  YEAR
# 0        1.0  2021
# 1        1.0  2021
# 2        1.0  2021
# 3        3.0  2021
# 4        1.0  2021
# ...      ...   ...
# 5439     1.0  2021
# 5440     2.0  2021
# 5441     4.0  2021
# 5442     4.0  2021
# 5443     3.0  2021
#
# [5444 rows x 54 columns]

# %%
#add year column
years = [2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012]

# Adding a new column with the respective year to each DataFrame
for (key, df), year in zip(ervdata.items(), years):
    df['YEAR'] = year

# %%
#read in codebooks
# years = ['2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012']
# ervCBs = {}

# ps, ervCBs = readCBs('erv', years, ervCBs)
# ps

# %%
#call function to export csvs
dest = 'erv'
dir = f'../data/{dest}'
dict = ervdata

shipData(dest, dir, dict)
# Out:
# data shipped!

# %% [markdown]
# #### *Office-Based Visits*

# %%
#call function to read in V9 files and add to dictionary
ids = ['h229g', 'h220g', 'h213g', 'h206g', 'h197g']
obvdata = {}

ps, obvdata = readV9('obv', ids, obvdata)

# %%
ps
# Out:
# ['Got it!', 'Got it!', 'Got it!', 'Got it!', 'Got it!']

# %%
#call function to read in SAS files and add to dictionary
ids = ['h188g', 'h178g', 'h168g', 'h160g', 'h152g']

ps, obvdata = readSAS('obv', ids, obvdata)

# %%
obvdata.keys()
# Out:
# dict_keys(['h229g', 'h220g', 'h213g', 'h206g', 'h197g', 'h188g', 'h178g', 'h168g', 'h160g', 'h152g'])

# %%
#call function to rename dfs to appropriate filenames
ids = ['h229g', 'h220g', 'h213g', 'h206g', 'h197g', 'h188g', 'h178g', 'h168g', 'h160g', 'h152g']

obvdata = renameMasters(obvdata, 2021, 'obv_data', ids)

# %%
obvdata['obv_data_2021']
# Out:
#              DUID    PID    DUPERSID           EVNTIDX  EVENTRN FFEEIDX  \
# 0       2320005.0  101.0  2320005101  2320005101202101      8.0      -1
# 1       2320005.0  101.0  2320005101  2320005101202201      8.0      -1
# 2       2320005.0  101.0  2320005101  2320005101202301      8.0      -1
# 3       2320005.0  101.0  2320005101  2320005101202401      8.0      -1
# 4       2320005.0  101.0  2320005101  2320005101202501      8.0      -1
# ...           ...    ...         ...               ...      ...     ...
# 202296  2689507.0  102.0  2689507102  2689507102000301      2.0      -1
# 202297  2689507.0  102.0  2689507102  2689507102000701      2.0      -1
# 202298  2689507.0  102.0  2689507102  2689507102001001      3.0      -1
# 202299  2689507.0  103.0  2689507103  2689507103001101      3.0      -1
# 202300  2689507.0  104.0  2689507104  2689507104001201      3.0      -1
#
#         PANEL  MPCELIG  MPCDATA  OBDATEYR  ...  OBSL21X  OBWC21X  OBOT21X  \
# 0        23.0      1.0      2.0    2021.0  ...      0.0      0.0      0.0
# 1        23.0      1.0      2.0    2021.0  ...      0.0      0.0      0.0
# 2        23.0      1.0      2.0    2021.0  ...      0.0      0.0      0.0
# 3        23.0      1.0      2.0    2021.0  ...      0.0      0.0      0.0
# 4        23.0      1.0      2.0    2021.0  ...      0.0      0.0      0.0
# ...       ...      ...      ...       ...  ...      ...      ...      ...
# 202296   26.0      1.0      2.0    2021.0  ...      0.0      0.0      0.0
# 202297   26.0      2.0      2.0    2021.0  ...      0.0      0.0      0.0
# 202298   26.0      1.0      2.0    2021.0  ...      0.0      0.0      0.0
# 202299   26.0      1.0      2.0    2021.0  ...      0.0      0.0      0.0
# 202300   26.0      1.0      2.0    2021.0  ...      0.0      0.0      0.0
#
#         OBXP21X  OBTC21X  IMPFLAG      PERWT21F  VARSTR  VARPSU  YEAR
# 0        695.24   826.53      3.0   6785.015684  2079.0     1.0  2021
# 1        896.93  1517.03      3.0   6785.015684  2079.0     1.0  2021
# 2        896.93  1517.03      3.0   6785.015684  2079.0     1.0  2021
# 3        695.24   826.53      3.0   6785.015684  2079.0     1.0  2021
# 4        695.24   826.53      3.0   6785.015684  2079.0     1.0  2021
# ...         ...      ...      ...           ...     ...     ...   ...
# 202296   125.75   269.60      4.0  34505.439704  2104.0     2.0  2021
# 202297    40.00    40.00      3.0  34505.439704  2104.0     2.0  2021
# 202298    52.54   145.17      4.0  34505.439704  2104.0     2.0  2021
# 202299   192.66   214.00      4.0  23975.435327  2104.0     2.0  2021
# 202300   192.66   214.00      4.0  27813.061477  2104.0     2.0  2021
#
# [202301 rows x 48 columns]

# %%
#add year column
years = [2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012]

# Adding a new column with the respective year to each DataFrame
for (key, df), year in zip(obvdata.items(), years):
    df['YEAR'] = year

# %%
#read in codebooks
# years = ['2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012']
# obvCBs = {}

# ps, obvCBs = readCBs('obv', years, obvCBs)
# ps

# %%
#call function to export csvs
dest = 'obv'
dir = f'../data/{dest}'
dict = obvdata

shipData(dest, dir, dict)
# Out:
# data shipped!
